# %% [markdown]
# # Лабораторная работа 4. Классификация. Деревья решений
#
# Яшакин Андрей 6132-010402D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, make_scorer, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree

# %% [markdown]
# ## 1. Считать датасет

# %%
df = pd.read_csv("housing.csv")
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
# Предобработка данных
df = df[['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms',
         'population', 'households', 'median_income', 'median_house_value', 'ocean_proximity']]
# Кодирование категориальных данных
df = pd.get_dummies(df, columns=['ocean_proximity'], drop_first=True)
# Преобразование целевой переменной в категории
df['median_house_value'] = pd.qcut(df['median_house_value'], q=3, labels=[0, 1, 2])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   longitude                   20433 non-null  float64
#  1   latitude                    20433 non-null  float64
#  2   housing_median_age          20433 non-null  float64
#  3   total_rooms                 20433 non-null  float64
#  4   total_bedrooms              20433 non-null  float64
#  5   population                  20433 non-null  float64
#  6   households                  20433 non-null  float64
#  7   median_income               20433 non-null  float64
#  8   median_house_value          20433 non-null  category
#  9   ocean_proximity_INLAND      20433 non-null  bool
#  10  ocean_proximity_ISLAND      20433 non-null  bool
#  11  ocean_proximity_NEAR BAY    20433 non-null  bool
#  12  ocean_proximity_NEAR OCEAN  20433 non-null  bool
# dtypes: bool(4), category(1), float64(8)
# memory usage: 1.5 MB

# %% [markdown]
# Сделали один из признаков категориальным, разбили на 3 класса, которые и будем предсказывать

# %% [markdown]
# ## 2. Провести анализ датасета

# %% [markdown]
# ### 2.1 Привести описание датасета

# %% [markdown]
# Датасет содержит данные о жилых районах в Калифорнии, состоящий из 20640 строк и 10 столбцов. Ниже приведены подробности о каждом столбце:
#
# longitude (float64): Долгота местоположения.
#
# latitude (float64): Широта местоположения.
#
# housing_median_age (float64): Средний возраст домов в районе.
#
# total_rooms (float64): Общее количество комнат в районе.
#
# total_bedrooms (float64): Общее количество спален в районе. (Примечание: содержит 20433 непустых значений из 20640)
#
# population (float64): Численность населения района.
#
# households (float64): Количество домохозяйств в районе.
#
# median_income (float64): Средний доход в районе.
#
# median_house_value (category): Средняя стоимость
# домов в районе, представлено 3 классами,
# условно: низкая, средня, высокая.
#
# ocean_proximity (object): Близость к океану, категориальный признак.

# %% [markdown]
# ### 2.2 Масштабирование данных и разбиение выборки

# %%
# Масштабирование данных
scaler = MinMaxScaler()
df.loc[:, df.columns != 'median_house_value'] = scaler.fit_transform(df.loc[:, df.columns != 'median_house_value'])

# Разделение на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(df.loc[:, df.columns != 'median_house_value'],
                                                    df['median_house_value'], test_size=0.33, random_state=42)

# %% [markdown]
# ## 3. Дерево решений

# %% [markdown]
# ### 3.1 С использованием GridSearchCV осуществить подбор гиперпараметра DecisionTreeClassifier

# %%
# Настройка параметров для GridSearchCV
parameters = {
    "criterion": ["gini", "entropy"],
    "splitter": ["best", "random"],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ['sqrt', 'log2', None]
}

# %%
# Определение оценок для классификации
scores = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='macro'),
    'recall': make_scorer(recall_score, average='macro'),
    'f1': make_scorer(f1_score, average='macro')
}

# %%
# Обучение и подбор параметров для DecisionTreeClassifier
clf_tree = GridSearchCV(DecisionTreeClassifier(), parameters, scoring=scores, refit='f1', cv=5, verbose=4)
clf_tree.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.717) f1: (test=0.719) precision: (test=0.721) recall: (test=0.717) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.706) f1: (test=0.705) precision: (test=0.704) recall: (test=0.706) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.704) f1: (test=0.704) precision: (test=0.704) recall: (test=0.704) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.698) f1: (test=0.698) precision: (test=0.698) recall: (test=0.698) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.692) f1: (test=0.694) precision: (test=0.698) recall: (test=0.692) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.666) f1: (test=0.667) precision: (test=0.668) recall: (test=0.666) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.684) f1: (test=0.685) precision: (test=0.686) recall: (test=0.684) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.687) f1: (test=0.687) precision: (test=0.688) recall: (test=0.687) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.692) f1: (test=0.693) precision: (test=0.693) recall: (test=0.693) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.667) f1: (test=0.667) precision: (test=0.668) recall: (test=0.667) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.704) f1: (test=0.706) precision: (test=0.708) recall: (test=0.704) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.703) f1: (test=0.701) precision: (test=0.701) recall: (test=0.703) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.682) f1: (test=0.683) precision: (test=0.685) recall: (test=0.682) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.691) f1: (test=0.691) precision: (test=0.692) recall: (test=0.691) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.711) f1: (test=0.712) precision: (test=0.713) recall: (test=0.712) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.680) f1: (test=0.681) precision: (test=0.683) recall: (test=0.680) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.697) f1: (test=0.696) precision: (test=0.698) recall: (test=0.697) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.698) f1: (test=0.696) precision: (test=0.696) recall: (test=0.698) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.698) f1: (test=0.697) precision: (test=0.699) recall: (test=0.699) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.690) f1: (test=0.689) precision: (test=0.693) recall: (test=0.690) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.701) f1: (test=0.701) precision: (test=0.702) recall: (test=0.701) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.709) f1: (test=0.709) precision: (test=0.709) recall: (test=0.709) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.714) f1: (test=0.714) precision: (test=0.713) recall: (test=0.714) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.701) f1: (test=0.700) precision: (test=0.700) recall: (test=0.701) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.716) f1: (test=0.717) precision: (test=0.719) recall: (test=0.716) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.702) f1: (test=0.701) precision: (test=0.702) recall: (test=0.702) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.715) f1: (test=0.714) precision: (test=0.714) recall: (test=0.716) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.683) f1: (test=0.681) precision: (test=0.679) recall: (test=0.683) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.706) f1: (test=0.705) precision: (test=0.705) recall: (test=0.706) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.701) f1: (test=0.699) precision: (test=0.700) recall: (test=0.701) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.685) f1: (test=0.685) precision: (test=0.688) recall: (test=0.685) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.731) f1: (test=0.731) precision: (test=0.733) recall: (test=0.731) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.721) f1: (test=0.720) precision: (test=0.721) recall: (test=0.721) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.706) f1: (test=0.707) precision: (test=0.711) recall: (test=0.707) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.705) f1: (test=0.704) precision: (test=0.709) recall: (test=0.705) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.702) f1: (test=0.702) precision: (test=0.704) recall: (test=0.702) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.709) f1: (test=0.703) precision: (test=0.704) recall: (test=0.709) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.674) f1: (test=0.672) precision: (test=0.676) recall: (test=0.674) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.684) f1: (test=0.676) precision: (test=0.684) recall: (test=0.684) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.679) f1: (test=0.681) precision: (test=0.689) recall: (test=0.680) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.702) f1: (test=0.703) precision: (test=0.705) recall: (test=0.702) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.705) f1: (test=0.703) precision: (test=0.705) recall: (test=0.705) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.714) f1: (test=0.715) precision: (test=0.718) recall: (test=0.714) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.690) f1: (test=0.689) precision: (test=0.692) recall: (test=0.690) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.694) f1: (test=0.695) precision: (test=0.700) recall: (test=0.694) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.663) f1: (test=0.663) precision: (test=0.665) recall: (test=0.663) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.684) f1: (test=0.681) precision: (test=0.682) recall: (test=0.684) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.706) f1: (test=0.705) precision: (test=0.705) recall: (test=0.706) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.687) f1: (test=0.685) precision: (test=0.686) recall: (test=0.687) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.674) f1: (test=0.672) precision: (test=0.676) recall: (test=0.675) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.711) f1: (test=0.712) precision: (test=0.714) recall: (test=0.711) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.718) f1: (test=0.718) precision: (test=0.718) recall: (test=0.718) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.700) f1: (test=0.700) precision: (test=0.701) recall: (test=0.700) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.704) f1: (test=0.704) precision: (test=0.705) recall: (test=0.704) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.712) f1: (test=0.713) precision: (test=0.714) recall: (test=0.712) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.708) f1: (test=0.707) precision: (test=0.708) recall: (test=0.708) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.703) f1: (test=0.702) precision: (test=0.704) recall: (test=0.704) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.684) f1: (test=0.689) precision: (test=0.708) recall: (test=0.684) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.699) f1: (test=0.696) precision: (test=0.695) recall: (test=0.699) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.706) f1: (test=0.703) precision: (test=0.704) recall: (test=0.706) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.701) f1: (test=0.702) precision: (test=0.704) recall: (test=0.701) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.704) f1: (test=0.705) precision: (test=0.706) recall: (test=0.704) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.713) f1: (test=0.714) precision: (test=0.715) recall: (test=0.713) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.716) f1: (test=0.716) precision: (test=0.717) recall: (test=0.716) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.731) f1: (test=0.732) precision: (test=0.736) recall: (test=0.731) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.652) f1: (test=0.657) precision: (test=0.687) recall: (test=0.652) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.691) f1: (test=0.687) precision: (test=0.687) recall: (test=0.691) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.679) f1: (test=0.678) precision: (test=0.677) recall: (test=0.679) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.701) f1: (test=0.701) precision: (test=0.706) recall: (test=0.701) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.669) f1: (test=0.667) precision: (test=0.670) recall: (test=0.669) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.733) f1: (test=0.734) precision: (test=0.735) recall: (test=0.733) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.721) f1: (test=0.722) precision: (test=0.723) recall: (test=0.721) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.720) f1: (test=0.721) precision: (test=0.723) recall: (test=0.720) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.711) f1: (test=0.712) precision: (test=0.714) recall: (test=0.711) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.698) f1: (test=0.698) precision: (test=0.700) recall: (test=0.699) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.675) f1: (test=0.674) precision: (test=0.674) recall: (test=0.675) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.693) f1: (test=0.687) precision: (test=0.686) recall: (test=0.693) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.663) f1: (test=0.649) precision: (test=0.650) recall: (test=0.664) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.644) f1: (test=0.638) precision: (test=0.639) recall: (test=0.644) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.664) f1: (test=0.660) precision: (test=0.660) recall: (test=0.664) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.695) f1: (test=0.696) precision: (test=0.698) recall: (test=0.696) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.732) f1: (test=0.731) precision: (test=0.732) recall: (test=0.732) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.720) f1: (test=0.719) precision: (test=0.718) recall: (test=0.720) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.711) f1: (test=0.710) precision: (test=0.712) recall: (test=0.711) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.710) f1: (test=0.710) precision: (test=0.713) recall: (test=0.710) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.664) f1: (test=0.666) precision: (test=0.670) recall: (test=0.664) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.693) f1: (test=0.689) precision: (test=0.688) recall: (test=0.693) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.696) f1: (test=0.703) precision: (test=0.725) recall: (test=0.696) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.611) f1: (test=0.603) precision: (test=0.660) recall: (test=0.611) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.620) f1: (test=0.623) precision: (test=0.640) recall: (test=0.620) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.701) f1: (test=0.702) precision: (test=0.702) recall: (test=0.701) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.694) f1: (test=0.694) precision: (test=0.694) recall: (test=0.694) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.695) f1: (test=0.694) precision: (test=0.694) recall: (test=0.695) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.704) f1: (test=0.703) precision: (test=0.703) recall: (test=0.704) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.699) f1: (test=0.700) precision: (test=0.700) recall: (test=0.699) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.681) f1: (test=0.681) precision: (test=0.682) recall: (test=0.681) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.675) f1: (test=0.675) precision: (test=0.675) recall: (test=0.675) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.688) f1: (test=0.690) precision: (test=0.692) recall: (test=0.689) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.678) f1: (test=0.677) precision: (test=0.677) recall: (test=0.678) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.667) f1: (test=0.668) precision: (test=0.668) recall: (test=0.667) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.702) f1: (test=0.702) precision: (test=0.703) recall: (test=0.702) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.714) f1: (test=0.714) precision: (test=0.715) recall: (test=0.714) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.706) f1: (test=0.706) precision: (test=0.707) recall: (test=0.706) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.706) f1: (test=0.705) precision: (test=0.705) recall: (test=0.706) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.699) f1: (test=0.700) precision: (test=0.701) recall: (test=0.700) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.683) f1: (test=0.683) precision: (test=0.686) recall: (test=0.683) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.675) f1: (test=0.674) precision: (test=0.676) recall: (test=0.675) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.674) f1: (test=0.673) precision: (test=0.673) recall: (test=0.674) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.664) f1: (test=0.664) precision: (test=0.668) recall: (test=0.665) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.673) f1: (test=0.673) precision: (test=0.676) recall: (test=0.674) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.729) f1: (test=0.729) precision: (test=0.729) recall: (test=0.729) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.717) f1: (test=0.717) precision: (test=0.717) recall: (test=0.717) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.724) f1: (test=0.724) precision: (test=0.725) recall: (test=0.724) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.721) f1: (test=0.720) precision: (test=0.721) recall: (test=0.721) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.696) f1: (test=0.696) precision: (test=0.696) recall: (test=0.696) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.691) f1: (test=0.691) precision: (test=0.691) recall: (test=0.691) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.701) f1: (test=0.701) precision: (test=0.703) recall: (test=0.701) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.683) f1: (test=0.684) precision: (test=0.687) recall: (test=0.683) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.714) f1: (test=0.716) precision: (test=0.721) recall: (test=0.715) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.709) f1: (test=0.709) precision: (test=0.712) recall: (test=0.709) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.732) f1: (test=0.733) precision: (test=0.737) recall: (test=0.732) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.725) f1: (test=0.725) precision: (test=0.729) recall: (test=0.725) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.711) f1: (test=0.710) precision: (test=0.710) recall: (test=0.711) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.663) f1: (test=0.652) precision: (test=0.657) recall: (test=0.663) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.711) f1: (test=0.710) precision: (test=0.712) recall: (test=0.711) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.665) f1: (test=0.668) precision: (test=0.682) recall: (test=0.666) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.670) f1: (test=0.661) precision: (test=0.667) recall: (test=0.670) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.690) f1: (test=0.689) precision: (test=0.690) recall: (test=0.690) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.687) f1: (test=0.685) precision: (test=0.689) recall: (test=0.688) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.680) f1: (test=0.680) precision: (test=0.686) recall: (test=0.681) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.706) f1: (test=0.707) precision: (test=0.709) recall: (test=0.706) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.702) f1: (test=0.702) precision: (test=0.702) recall: (test=0.702) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.702) f1: (test=0.701) precision: (test=0.701) recall: (test=0.702) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.687) f1: (test=0.687) precision: (test=0.689) recall: (test=0.688) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.692) f1: (test=0.692) precision: (test=0.693) recall: (test=0.692) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.687) f1: (test=0.688) precision: (test=0.697) recall: (test=0.687) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.668) f1: (test=0.666) precision: (test=0.670) recall: (test=0.669) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.689) f1: (test=0.691) precision: (test=0.696) recall: (test=0.689) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.699) f1: (test=0.697) precision: (test=0.696) recall: (test=0.699) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.650) f1: (test=0.646) precision: (test=0.646) recall: (test=0.650) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.699) f1: (test=0.701) precision: (test=0.704) recall: (test=0.699) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.715) f1: (test=0.714) precision: (test=0.714) recall: (test=0.715) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.714) recall: (test=0.713) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.710) f1: (test=0.710) precision: (test=0.710) recall: (test=0.711) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.712) f1: (test=0.712) precision: (test=0.713) recall: (test=0.712) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.700) f1: (test=0.701) precision: (test=0.703) recall: (test=0.700) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.707) f1: (test=0.705) precision: (test=0.704) recall: (test=0.707) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.670) f1: (test=0.672) precision: (test=0.679) recall: (test=0.670) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.700) f1: (test=0.698) precision: (test=0.703) recall: (test=0.700) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.695) f1: (test=0.692) precision: (test=0.694) recall: (test=0.695) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.710) f1: (test=0.710) precision: (test=0.712) recall: (test=0.710) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.692) f1: (test=0.693) precision: (test=0.694) recall: (test=0.692) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.691) f1: (test=0.690) precision: (test=0.691) recall: (test=0.691) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.709) f1: (test=0.709) precision: (test=0.710) recall: (test=0.709) total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.685) f1: (test=0.685) precision: (test=0.687) recall: (test=0.685) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.664) f1: (test=0.663) precision: (test=0.663) recall: (test=0.664) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.691) f1: (test=0.686) precision: (test=0.686) recall: (test=0.692) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.695) f1: (test=0.695) precision: (test=0.698) recall: (test=0.695) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.629) f1: (test=0.615) precision: (test=0.622) recall: (test=0.629) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.669) f1: (test=0.668) precision: (test=0.667) recall: (test=0.669) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.697) f1: (test=0.698) precision: (test=0.700) recall: (test=0.697) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.730) f1: (test=0.730) precision: (test=0.730) recall: (test=0.731) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.729) f1: (test=0.730) precision: (test=0.732) recall: (test=0.729) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.714) f1: (test=0.712) precision: (test=0.713) recall: (test=0.714) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.719) f1: (test=0.719) precision: (test=0.720) recall: (test=0.719) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.686) f1: (test=0.686) precision: (test=0.688) recall: (test=0.686) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.725) f1: (test=0.722) precision: (test=0.723) recall: (test=0.725) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.688) f1: (test=0.694) precision: (test=0.715) recall: (test=0.688) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.662) f1: (test=0.657) precision: (test=0.661) recall: (test=0.662) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.666) f1: (test=0.667) precision: (test=0.676) recall: (test=0.666) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.702) f1: (test=0.702) precision: (test=0.703) recall: (test=0.702) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.709) f1: (test=0.709) precision: (test=0.709) recall: (test=0.709) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.725) f1: (test=0.725) precision: (test=0.725) recall: (test=0.725) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.713) recall: (test=0.713) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.715) f1: (test=0.715) precision: (test=0.716) recall: (test=0.715) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.676) f1: (test=0.672) precision: (test=0.671) recall: (test=0.676) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.646) f1: (test=0.624) precision: (test=0.634) recall: (test=0.646) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.641) f1: (test=0.632) precision: (test=0.647) recall: (test=0.641) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.690) f1: (test=0.689) precision: (test=0.690) recall: (test=0.690) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.637) f1: (test=0.631) precision: (test=0.631) recall: (test=0.637) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.749) f1: (test=0.749) precision: (test=0.750) recall: (test=0.749) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.739) f1: (test=0.739) precision: (test=0.738) recall: (test=0.739) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.743) f1: (test=0.743) precision: (test=0.744) recall: (test=0.743) total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.729) f1: (test=0.729) precision: (test=0.729) recall: (test=0.729) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.746) f1: (test=0.746) precision: (test=0.746) recall: (test=0.746) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.701) f1: (test=0.701) precision: (test=0.702) recall: (test=0.701) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.720) f1: (test=0.719) precision: (test=0.718) recall: (test=0.720) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.715) f1: (test=0.716) precision: (test=0.717) recall: (test=0.716) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.677) f1: (test=0.677) precision: (test=0.678) recall: (test=0.677) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.696) f1: (test=0.696) precision: (test=0.696) recall: (test=0.696) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.747) f1: (test=0.748) precision: (test=0.749) recall: (test=0.747) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.739) f1: (test=0.739) precision: (test=0.739) recall: (test=0.739) total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.751) f1: (test=0.752) precision: (test=0.752) recall: (test=0.751) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.736) f1: (test=0.735) precision: (test=0.735) recall: (test=0.736) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.739) f1: (test=0.739) precision: (test=0.740) recall: (test=0.739) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.694) f1: (test=0.694) precision: (test=0.695) recall: (test=0.694) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.709) f1: (test=0.710) precision: (test=0.711) recall: (test=0.709) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.690) f1: (test=0.689) precision: (test=0.688) recall: (test=0.690) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.718) f1: (test=0.717) precision: (test=0.718) recall: (test=0.718) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.702) f1: (test=0.702) precision: (test=0.704) recall: (test=0.702) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.753) f1: (test=0.754) precision: (test=0.755) recall: (test=0.753) total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.750) f1: (test=0.750) precision: (test=0.750) recall: (test=0.750) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.751) f1: (test=0.751) precision: (test=0.752) recall: (test=0.751) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.743) f1: (test=0.743) precision: (test=0.743) recall: (test=0.743) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.740) f1: (test=0.740) precision: (test=0.742) recall: (test=0.740) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.720) f1: (test=0.721) precision: (test=0.722) recall: (test=0.720) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.733) f1: (test=0.732) precision: (test=0.731) recall: (test=0.734) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.738) f1: (test=0.739) precision: (test=0.740) recall: (test=0.738) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.719) f1: (test=0.719) precision: (test=0.720) recall: (test=0.719) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.726) f1: (test=0.727) precision: (test=0.728) recall: (test=0.726) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.749) f1: (test=0.749) precision: (test=0.749) recall: (test=0.749) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.736) f1: (test=0.735) precision: (test=0.736) recall: (test=0.736) total time=   0.1s
# ...
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.740) f1: (test=0.740) precision: (test=0.740) recall: (test=0.740) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.739) f1: (test=0.739) precision: (test=0.741) recall: (test=0.739) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.721) f1: (test=0.723) precision: (test=0.729) recall: (test=0.721) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.711) f1: (test=0.712) precision: (test=0.713) recall: (test=0.712) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.722) f1: (test=0.723) precision: (test=0.724) recall: (test=0.722) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.711) f1: (test=0.710) precision: (test=0.710) recall: (test=0.711) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.715) f1: (test=0.715) precision: (test=0.716) recall: (test=0.715) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.745) f1: (test=0.746) precision: (test=0.747) recall: (test=0.746) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.751) f1: (test=0.752) precision: (test=0.754) recall: (test=0.751) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.750) f1: (test=0.750) precision: (test=0.750) recall: (test=0.750) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.743) f1: (test=0.741) precision: (test=0.741) recall: (test=0.743) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.734) f1: (test=0.735) precision: (test=0.737) recall: (test=0.735) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.691) f1: (test=0.692) precision: (test=0.695) recall: (test=0.692) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.692) f1: (test=0.692) precision: (test=0.696) recall: (test=0.692) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.726) f1: (test=0.726) precision: (test=0.727) recall: (test=0.726) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.722) f1: (test=0.720) precision: (test=0.723) recall: (test=0.723) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.699) f1: (test=0.699) precision: (test=0.704) recall: (test=0.699) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.744) f1: (test=0.745) precision: (test=0.746) recall: (test=0.744) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.756) f1: (test=0.757) precision: (test=0.758) recall: (test=0.756) total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.759) f1: (test=0.759) precision: (test=0.759) recall: (test=0.759) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.738) f1: (test=0.737) precision: (test=0.736) recall: (test=0.738) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.741) f1: (test=0.741) precision: (test=0.743) recall: (test=0.741) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.686) f1: (test=0.686) precision: (test=0.687) recall: (test=0.686) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.720) f1: (test=0.720) precision: (test=0.723) recall: (test=0.720) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.718) f1: (test=0.720) precision: (test=0.725) recall: (test=0.718) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.715) recall: (test=0.713) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.702) f1: (test=0.702) precision: (test=0.704) recall: (test=0.702) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.756) f1: (test=0.756) precision: (test=0.758) recall: (test=0.756) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.754) f1: (test=0.755) precision: (test=0.756) recall: (test=0.754) total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.752) f1: (test=0.751) precision: (test=0.751) recall: (test=0.752) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.747) f1: (test=0.747) precision: (test=0.747) recall: (test=0.747) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.744) f1: (test=0.744) precision: (test=0.746) recall: (test=0.744) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.734) f1: (test=0.734) precision: (test=0.735) recall: (test=0.734) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.736) f1: (test=0.736) precision: (test=0.737) recall: (test=0.736) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.721) f1: (test=0.720) precision: (test=0.720) recall: (test=0.721) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.738) f1: (test=0.738) precision: (test=0.739) recall: (test=0.739) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.715) f1: (test=0.713) precision: (test=0.713) recall: (test=0.715) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.745) f1: (test=0.746) precision: (test=0.748) recall: (test=0.746) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.767) f1: (test=0.768) precision: (test=0.768) recall: (test=0.767) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.749) f1: (test=0.750) precision: (test=0.751) recall: (test=0.749) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.748) f1: (test=0.747) precision: (test=0.747) recall: (test=0.748) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.763) f1: (test=0.764) precision: (test=0.765) recall: (test=0.764) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.710) f1: (test=0.711) precision: (test=0.713) recall: (test=0.710) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.715) f1: (test=0.714) precision: (test=0.714) recall: (test=0.715) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.740) f1: (test=0.739) precision: (test=0.739) recall: (test=0.740) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.715) recall: (test=0.713) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.706) f1: (test=0.706) precision: (test=0.707) recall: (test=0.707) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.746) f1: (test=0.747) precision: (test=0.748) recall: (test=0.746) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.764) f1: (test=0.764) precision: (test=0.764) recall: (test=0.764) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.750) f1: (test=0.751) precision: (test=0.752) recall: (test=0.750) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.748) f1: (test=0.747) precision: (test=0.747) recall: (test=0.749) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.763) f1: (test=0.764) precision: (test=0.765) recall: (test=0.763) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.713) f1: (test=0.714) precision: (test=0.715) recall: (test=0.713) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.736) f1: (test=0.736) precision: (test=0.737) recall: (test=0.736) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.746) f1: (test=0.746) precision: (test=0.747) recall: (test=0.746) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.751) f1: (test=0.750) precision: (test=0.752) recall: (test=0.751) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.715) f1: (test=0.714) precision: (test=0.714) recall: (test=0.715) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.752) f1: (test=0.753) precision: (test=0.754) recall: (test=0.752) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.765) f1: (test=0.766) precision: (test=0.766) recall: (test=0.765) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.747) f1: (test=0.748) precision: (test=0.748) recall: (test=0.747) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.749) f1: (test=0.748) precision: (test=0.747) recall: (test=0.749) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.765) f1: (test=0.765) precision: (test=0.767) recall: (test=0.765) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.721) f1: (test=0.722) precision: (test=0.724) recall: (test=0.721) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.726) f1: (test=0.726) precision: (test=0.728) recall: (test=0.726) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.733) f1: (test=0.734) precision: (test=0.736) recall: (test=0.733) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.712) f1: (test=0.711) precision: (test=0.713) recall: (test=0.712) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.720) f1: (test=0.719) precision: (test=0.719) recall: (test=0.720) total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              refit='f1',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'f1': make_scorer(f1_score, average=macro),
#                       'precision': make_scorer(precision_score, average=macro),
#                       'recall': make_scorer(recall_score, average=macro)},
#              verbose=4)

# %% [markdown]
# ### 3.2 Вывести гиперпараметры лучшей модели и ее метрики

# %%
print("Лучшие параметры для DecisionTreeClassifier: ")
print(clf_tree.best_params_)
# Out:
# Лучшие параметры для DecisionTreeClassifier:
# {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}

# %%
results_tree = pd.DataFrame(clf_tree.cv_results_)
best_result_tree = results_tree[results_tree['rank_test_f1'] == 1]
print(f"Accuracy: {best_result_tree['mean_test_accuracy'].values[0]}")
print(f"Precision: {best_result_tree['mean_test_precision'].values[0]}")
print(f"Recall: {best_result_tree['mean_test_recall'].values[0]}")
print(f"F1: {best_result_tree['mean_test_f1'].values[0]}")
# Out:
# Accuracy: 0.7601899196493791
# Precision: 0.765313489153228
# Recall: 0.760283486275068
# F1: 0.7619043418550726

# %% [markdown]
# ### 3.3 Вывести `feature_importance`

# %%
# Важность признаков
feature_importance_tree = {X_train.columns[i]: clf_tree.best_estimator_.feature_importances_[i] for i in range(len(X_train.columns))}
feature_importance_items_tree = sorted(feature_importance_tree.items(), key=lambda x: x[1])
feature_importance_tree = dict(feature_importance_items_tree)
print("Feature importances for DecisionTreeClassifier:")
print(feature_importance_tree)
# Out:
# Feature importances for DecisionTreeClassifier:
# {'ocean_proximity_ISLAND': 0.0, 'ocean_proximity_NEAR BAY': 0.0, 'households': 0.01134272389672246, 'ocean_proximity_NEAR OCEAN': 0.013169185774865913, 'total_rooms': 0.015259984922914315, 'total_bedrooms': 0.01695302621555972, 'population': 0.02030797294023238, 'housing_median_age': 0.02747089859008973, 'latitude': 0.13783742994449297, 'longitude': 0.18344119144595508, 'ocean_proximity_INLAND': 0.24477080001012044, 'median_income': 0.32944678625904705}

# %% [markdown]
# Как мы видим 2 признака не влияют на среднюю стоимость по району, поэтому дальше мы их убираем, также убираем два наименее значимых признака и берем только 8 лучших признаков

# %% [markdown]
# ### 3.4. Осуществить фильтрацию признаков

# %%
# Выбор наиболее важных признаков
important_features = list(feature_importance_tree.keys())[-8:]  # Топ-8 признаков

# %%
# Перетренировка модели с использованием только важных признаков
X_train_f = X_train[important_features]
X_test_f = X_test[important_features]

# %% [markdown]
# ### 3.5. GridSearch на отфильтрованных данных и вывод лучших гиперпараметров

# %%
clf_tree = GridSearchCV(DecisionTreeClassifier(), parameters, scoring=scores, refit='f1', cv=5, verbose=4)
clf_tree.fit(X_train_f, y_train)
print("Лучшие параметры после отбора признаков: ")
print(clf_tree.best_params_)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.711) f1: (test=0.713) precision: (test=0.714) recall: (test=0.711) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.725) f1: (test=0.724) precision: (test=0.724) recall: (test=0.725) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.713) f1: (test=0.712) precision: (test=0.712) recall: (test=0.713) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.693) f1: (test=0.693) precision: (test=0.693) recall: (test=0.693) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.682) f1: (test=0.683) precision: (test=0.685) recall: (test=0.682) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.662) f1: (test=0.663) precision: (test=0.665) recall: (test=0.662) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.683) f1: (test=0.683) precision: (test=0.682) recall: (test=0.683) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.682) f1: (test=0.684) precision: (test=0.685) recall: (test=0.682) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.682) f1: (test=0.682) precision: (test=0.682) recall: (test=0.682) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.654) f1: (test=0.653) precision: (test=0.653) recall: (test=0.654) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.672) f1: (test=0.673) precision: (test=0.674) recall: (test=0.672) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.701) f1: (test=0.702) precision: (test=0.702) recall: (test=0.701) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.722) f1: (test=0.722) precision: (test=0.721) recall: (test=0.723) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.687) f1: (test=0.687) precision: (test=0.688) recall: (test=0.687) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.684) f1: (test=0.685) precision: (test=0.686) recall: (test=0.685) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.675) f1: (test=0.675) precision: (test=0.676) recall: (test=0.675) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.674) f1: (test=0.673) precision: (test=0.674) recall: (test=0.674) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.685) f1: (test=0.684) precision: (test=0.685) recall: (test=0.685) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.702) f1: (test=0.701) precision: (test=0.703) recall: (test=0.703) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.685) f1: (test=0.684) precision: (test=0.688) recall: (test=0.685) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.728) f1: (test=0.728) precision: (test=0.728) recall: (test=0.728) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.732) f1: (test=0.734) precision: (test=0.738) recall: (test=0.732) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.700) f1: (test=0.699) precision: (test=0.699) recall: (test=0.700) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.704) f1: (test=0.703) precision: (test=0.702) recall: (test=0.704) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.688) f1: (test=0.688) precision: (test=0.690) recall: (test=0.688) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.700) f1: (test=0.700) precision: (test=0.701) recall: (test=0.700) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.679) f1: (test=0.677) precision: (test=0.677) recall: (test=0.680) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.695) f1: (test=0.694) precision: (test=0.694) recall: (test=0.695) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.694) f1: (test=0.693) precision: (test=0.695) recall: (test=0.694) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.710) f1: (test=0.710) precision: (test=0.712) recall: (test=0.711) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.699) f1: (test=0.698) precision: (test=0.699) recall: (test=0.699) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.695) f1: (test=0.695) precision: (test=0.697) recall: (test=0.696) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.712) f1: (test=0.711) precision: (test=0.712) recall: (test=0.712) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.710) f1: (test=0.709) precision: (test=0.711) recall: (test=0.711) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.705) f1: (test=0.705) precision: (test=0.710) recall: (test=0.705) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.664) f1: (test=0.662) precision: (test=0.664) recall: (test=0.664) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.673) f1: (test=0.673) precision: (test=0.682) recall: (test=0.674) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.654) f1: (test=0.650) precision: (test=0.650) recall: (test=0.654) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.682) f1: (test=0.680) precision: (test=0.682) recall: (test=0.682) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.667) f1: (test=0.667) precision: (test=0.669) recall: (test=0.667) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.703) f1: (test=0.702) precision: (test=0.704) recall: (test=0.703) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.711) f1: (test=0.711) precision: (test=0.711) recall: (test=0.712) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.698) f1: (test=0.697) precision: (test=0.697) recall: (test=0.698) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.703) f1: (test=0.703) precision: (test=0.705) recall: (test=0.703) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.678) f1: (test=0.677) precision: (test=0.678) recall: (test=0.678) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.669) f1: (test=0.671) precision: (test=0.677) recall: (test=0.670) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.661) f1: (test=0.653) precision: (test=0.654) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.677) f1: (test=0.675) precision: (test=0.675) recall: (test=0.677) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.675) f1: (test=0.675) precision: (test=0.679) recall: (test=0.675) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.639) f1: (test=0.642) precision: (test=0.651) recall: (test=0.639) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.729) f1: (test=0.730) precision: (test=0.732) recall: (test=0.729) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.709) f1: (test=0.710) precision: (test=0.712) recall: (test=0.709) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.695) f1: (test=0.695) precision: (test=0.695) recall: (test=0.695) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.709) f1: (test=0.708) precision: (test=0.709) recall: (test=0.709) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.713) f1: (test=0.714) precision: (test=0.717) recall: (test=0.713) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.683) f1: (test=0.683) precision: (test=0.683) recall: (test=0.684) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.689) f1: (test=0.686) precision: (test=0.684) recall: (test=0.689) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.661) f1: (test=0.659) precision: (test=0.661) recall: (test=0.661) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.694) f1: (test=0.689) precision: (test=0.689) recall: (test=0.694) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.682) f1: (test=0.677) precision: (test=0.677) recall: (test=0.682) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.690) f1: (test=0.691) precision: (test=0.695) recall: (test=0.690) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.688) f1: (test=0.688) precision: (test=0.689) recall: (test=0.688) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.721) f1: (test=0.721) precision: (test=0.720) recall: (test=0.721) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.708) f1: (test=0.708) precision: (test=0.708) recall: (test=0.708) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.694) f1: (test=0.694) precision: (test=0.695) recall: (test=0.694) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.614) f1: (test=0.619) precision: (test=0.639) recall: (test=0.614) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.680) f1: (test=0.681) precision: (test=0.681) recall: (test=0.681) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.669) f1: (test=0.673) precision: (test=0.702) recall: (test=0.669) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.670) f1: (test=0.665) precision: (test=0.664) recall: (test=0.670) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.638) f1: (test=0.638) precision: (test=0.645) recall: (test=0.639) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.700) f1: (test=0.700) precision: (test=0.701) recall: (test=0.700) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.715) f1: (test=0.715) precision: (test=0.716) recall: (test=0.716) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.731) f1: (test=0.731) precision: (test=0.731) recall: (test=0.731) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.705) f1: (test=0.703) precision: (test=0.704) recall: (test=0.705) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.668) f1: (test=0.667) precision: (test=0.669) recall: (test=0.669) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.629) f1: (test=0.634) precision: (test=0.660) recall: (test=0.629) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.652) f1: (test=0.648) precision: (test=0.646) recall: (test=0.652) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.657) f1: (test=0.658) precision: (test=0.658) recall: (test=0.657) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.666) f1: (test=0.662) precision: (test=0.661) recall: (test=0.666) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.668) f1: (test=0.670) precision: (test=0.677) recall: (test=0.669) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.711) f1: (test=0.712) precision: (test=0.715) recall: (test=0.711) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.714) f1: (test=0.711) precision: (test=0.710) recall: (test=0.715) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.733) f1: (test=0.733) precision: (test=0.733) recall: (test=0.733) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.721) f1: (test=0.720) precision: (test=0.721) recall: (test=0.721) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.735) f1: (test=0.735) precision: (test=0.736) recall: (test=0.735) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.657) f1: (test=0.651) precision: (test=0.652) recall: (test=0.658) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.661) f1: (test=0.662) precision: (test=0.665) recall: (test=0.661) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.633) f1: (test=0.626) precision: (test=0.638) recall: (test=0.633) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.667) f1: (test=0.661) precision: (test=0.661) recall: (test=0.667) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.670) f1: (test=0.664) precision: (test=0.662) recall: (test=0.670) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.688) f1: (test=0.690) precision: (test=0.694) recall: (test=0.688) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.723) f1: (test=0.724) precision: (test=0.724) recall: (test=0.723) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.705) f1: (test=0.706) precision: (test=0.708) recall: (test=0.705) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.710) f1: (test=0.709) precision: (test=0.709) recall: (test=0.710) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.711) f1: (test=0.712) precision: (test=0.713) recall: (test=0.711) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.699) f1: (test=0.698) precision: (test=0.699) recall: (test=0.699) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.686) f1: (test=0.687) precision: (test=0.688) recall: (test=0.686) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.698) f1: (test=0.699) precision: (test=0.699) recall: (test=0.698) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.673) f1: (test=0.674) precision: (test=0.674) recall: (test=0.674) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.678) f1: (test=0.679) precision: (test=0.680) recall: (test=0.678) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.726) f1: (test=0.726) precision: (test=0.727) recall: (test=0.726) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.717) f1: (test=0.718) precision: (test=0.719) recall: (test=0.717) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.721) f1: (test=0.720) precision: (test=0.720) recall: (test=0.721) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.713) f1: (test=0.712) precision: (test=0.712) recall: (test=0.713) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.691) f1: (test=0.692) precision: (test=0.693) recall: (test=0.691) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.687) f1: (test=0.688) precision: (test=0.692) recall: (test=0.687) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.712) f1: (test=0.712) precision: (test=0.714) recall: (test=0.712) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.685) f1: (test=0.683) precision: (test=0.683) recall: (test=0.685) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.695) f1: (test=0.696) precision: (test=0.698) recall: (test=0.695) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.688) f1: (test=0.688) precision: (test=0.692) recall: (test=0.689) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.733) f1: (test=0.735) precision: (test=0.738) recall: (test=0.733) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.717) f1: (test=0.717) precision: (test=0.718) recall: (test=0.717) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.707) f1: (test=0.708) precision: (test=0.708) recall: (test=0.708) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.710) f1: (test=0.710) precision: (test=0.710) recall: (test=0.711) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.725) f1: (test=0.726) precision: (test=0.727) recall: (test=0.726) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.709) f1: (test=0.708) precision: (test=0.709) recall: (test=0.709) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.717) f1: (test=0.715) precision: (test=0.715) recall: (test=0.717) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.696) f1: (test=0.696) precision: (test=0.696) recall: (test=0.697) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.724) f1: (test=0.722) precision: (test=0.722) recall: (test=0.724) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.706) f1: (test=0.707) precision: (test=0.712) recall: (test=0.706) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.702) f1: (test=0.703) precision: (test=0.705) recall: (test=0.702) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.730) f1: (test=0.729) precision: (test=0.731) recall: (test=0.730) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.709) f1: (test=0.707) precision: (test=0.708) recall: (test=0.709) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.718) f1: (test=0.717) precision: (test=0.719) recall: (test=0.719) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.706) f1: (test=0.706) precision: (test=0.709) recall: (test=0.707) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.686) f1: (test=0.687) precision: (test=0.693) recall: (test=0.686) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.709) f1: (test=0.707) precision: (test=0.710) recall: (test=0.709) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.684) f1: (test=0.681) precision: (test=0.682) recall: (test=0.684) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.673) f1: (test=0.672) precision: (test=0.679) recall: (test=0.673) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.678) f1: (test=0.678) precision: (test=0.682) recall: (test=0.679) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.717) f1: (test=0.718) precision: (test=0.722) recall: (test=0.717) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.729) f1: (test=0.728) precision: (test=0.729) recall: (test=0.729) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.725) f1: (test=0.724) precision: (test=0.723) recall: (test=0.725) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.711) f1: (test=0.710) precision: (test=0.712) recall: (test=0.711) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.696) f1: (test=0.695) precision: (test=0.699) recall: (test=0.696) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.695) f1: (test=0.694) precision: (test=0.698) recall: (test=0.695) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.705) f1: (test=0.703) precision: (test=0.707) recall: (test=0.705) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.707) f1: (test=0.707) precision: (test=0.709) recall: (test=0.707) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.676) f1: (test=0.673) precision: (test=0.674) recall: (test=0.676) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.687) f1: (test=0.685) precision: (test=0.687) recall: (test=0.687) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.736) f1: (test=0.737) precision: (test=0.740) recall: (test=0.736) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.716) f1: (test=0.716) precision: (test=0.716) recall: (test=0.716) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.710) f1: (test=0.710) precision: (test=0.712) recall: (test=0.710) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.725) f1: (test=0.724) precision: (test=0.724) recall: (test=0.726) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.738) f1: (test=0.739) precision: (test=0.740) recall: (test=0.738) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.724) f1: (test=0.724) precision: (test=0.727) recall: (test=0.724) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.700) f1: (test=0.698) precision: (test=0.698) recall: (test=0.700) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.697) f1: (test=0.696) precision: (test=0.696) recall: (test=0.697) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.695) f1: (test=0.694) precision: (test=0.697) recall: (test=0.695) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.701) f1: (test=0.701) precision: (test=0.704) recall: (test=0.701) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.728) f1: (test=0.728) precision: (test=0.728) recall: (test=0.728) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.738) f1: (test=0.738) precision: (test=0.738) recall: (test=0.739) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.717) f1: (test=0.717) precision: (test=0.717) recall: (test=0.717) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.737) f1: (test=0.734) precision: (test=0.733) recall: (test=0.737) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.723) f1: (test=0.724) precision: (test=0.727) recall: (test=0.723) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.689) f1: (test=0.690) precision: (test=0.695) recall: (test=0.689) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.703) f1: (test=0.702) precision: (test=0.706) recall: (test=0.703) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.694) f1: (test=0.694) precision: (test=0.697) recall: (test=0.694) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.669) f1: (test=0.664) precision: (test=0.671) recall: (test=0.669) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.696) f1: (test=0.694) precision: (test=0.699) recall: (test=0.697) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.721) f1: (test=0.721) precision: (test=0.723) recall: (test=0.721) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.741) f1: (test=0.739) precision: (test=0.739) recall: (test=0.742) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.711) f1: (test=0.712) precision: (test=0.712) recall: (test=0.711) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.693) f1: (test=0.692) precision: (test=0.692) recall: (test=0.693) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.744) f1: (test=0.745) precision: (test=0.747) recall: (test=0.745) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.683) f1: (test=0.680) precision: (test=0.679) recall: (test=0.684) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.690) f1: (test=0.688) precision: (test=0.688) recall: (test=0.690) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.707) f1: (test=0.707) precision: (test=0.708) recall: (test=0.707) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.685) f1: (test=0.685) precision: (test=0.689) recall: (test=0.685) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.669) f1: (test=0.662) precision: (test=0.664) recall: (test=0.670) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.730) f1: (test=0.731) precision: (test=0.733) recall: (test=0.731) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.735) f1: (test=0.735) precision: (test=0.736) recall: (test=0.735) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.733) f1: (test=0.733) precision: (test=0.733) recall: (test=0.733) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.731) f1: (test=0.731) precision: (test=0.731) recall: (test=0.731) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.725) f1: (test=0.726) precision: (test=0.729) recall: (test=0.725) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.703) f1: (test=0.704) precision: (test=0.705) recall: (test=0.703) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.731) f1: (test=0.730) precision: (test=0.729) recall: (test=0.731) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.713) f1: (test=0.711) precision: (test=0.711) recall: (test=0.713) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.703) f1: (test=0.699) precision: (test=0.702) recall: (test=0.704) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.692) f1: (test=0.692) precision: (test=0.695) recall: (test=0.692) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.737) f1: (test=0.738) precision: (test=0.739) recall: (test=0.737) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.731) f1: (test=0.731) precision: (test=0.730) recall: (test=0.731) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.737) f1: (test=0.738) precision: (test=0.738) recall: (test=0.737) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.725) f1: (test=0.724) precision: (test=0.723) recall: (test=0.725) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best; accuracy: (test=0.744) f1: (test=0.745) precision: (test=0.745) recall: (test=0.745) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.713) recall: (test=0.713) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.692) f1: (test=0.692) precision: (test=0.692) recall: (test=0.693) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.692) f1: (test=0.692) precision: (test=0.693) recall: (test=0.692) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.693) f1: (test=0.693) precision: (test=0.693) recall: (test=0.693) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random; accuracy: (test=0.696) f1: (test=0.697) precision: (test=0.698) recall: (test=0.696) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.738) f1: (test=0.739) precision: (test=0.739) recall: (test=0.739) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.742) f1: (test=0.743) precision: (test=0.744) recall: (test=0.742) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.744) f1: (test=0.745) precision: (test=0.746) recall: (test=0.744) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.729) f1: (test=0.727) precision: (test=0.727) recall: (test=0.729) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=best; accuracy: (test=0.743) f1: (test=0.744) precision: (test=0.746) recall: (test=0.743) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.724) f1: (test=0.724) precision: (test=0.726) recall: (test=0.724) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.719) f1: (test=0.719) precision: (test=0.720) recall: (test=0.719) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.718) f1: (test=0.718) precision: (test=0.718) recall: (test=0.718) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.715) f1: (test=0.716) precision: (test=0.718) recall: (test=0.715) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5, splitter=random; accuracy: (test=0.722) f1: (test=0.723) precision: (test=0.724) recall: (test=0.723) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.747) f1: (test=0.747) precision: (test=0.748) recall: (test=0.747) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.745) f1: (test=0.745) precision: (test=0.745) recall: (test=0.745) total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.739) f1: (test=0.740) precision: (test=0.740) recall: (test=0.739) total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.733) f1: (test=0.731) precision: (test=0.731) recall: (test=0.733) total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.743) f1: (test=0.744) precision: (test=0.747) recall: (test=0.743) total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.715) f1: (test=0.715) precision: (test=0.716) recall: (test=0.715) total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.719) f1: (test=0.718) precision: (test=0.718) recall: (test=0.719) total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.723) f1: (test=0.723) precision: (test=0.723) recall: (test=0.723) total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.725) f1: (test=0.723) precision: (test=0.723) recall: (test=0.725) total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.722) f1: (test=0.721) precision: (test=0.723) recall: (test=0.722) total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.737) f1: (test=0.737) precision: (test=0.738) recall: (test=0.737) total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.734) f1: (test=0.734) precision: (test=0.735) recall: (test=0.734) total time=   0.1s
# ...
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.757) f1: (test=0.758) precision: (test=0.758) recall: (test=0.758) total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.756) f1: (test=0.756) precision: (test=0.756) recall: (test=0.756) total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.747) f1: (test=0.746) precision: (test=0.746) recall: (test=0.747) total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=best; accuracy: (test=0.738) f1: (test=0.738) precision: (test=0.738) recall: (test=0.738) total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.706) f1: (test=0.708) precision: (test=0.711) recall: (test=0.706) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.722) f1: (test=0.720) precision: (test=0.719) recall: (test=0.722) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.695) f1: (test=0.695) precision: (test=0.695) recall: (test=0.695) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.710) f1: (test=0.708) precision: (test=0.710) recall: (test=0.710) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=10, splitter=random; accuracy: (test=0.741) f1: (test=0.742) precision: (test=0.745) recall: (test=0.742) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.743) f1: (test=0.743) precision: (test=0.744) recall: (test=0.743) total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.755) f1: (test=0.755) precision: (test=0.756) recall: (test=0.755) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.748) f1: (test=0.749) precision: (test=0.749) recall: (test=0.748) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.746) f1: (test=0.745) precision: (test=0.745) recall: (test=0.746) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=best; accuracy: (test=0.726) f1: (test=0.726) precision: (test=0.728) recall: (test=0.726) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.704) f1: (test=0.704) precision: (test=0.704) recall: (test=0.704) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.706) f1: (test=0.704) precision: (test=0.705) recall: (test=0.706) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.726) f1: (test=0.726) precision: (test=0.728) recall: (test=0.726) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.736) f1: (test=0.736) precision: (test=0.740) recall: (test=0.736) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=2, splitter=random; accuracy: (test=0.699) f1: (test=0.700) precision: (test=0.702) recall: (test=0.699) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.743) f1: (test=0.743) precision: (test=0.744) recall: (test=0.743) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.749) f1: (test=0.749) precision: (test=0.750) recall: (test=0.749) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.753) f1: (test=0.754) precision: (test=0.754) recall: (test=0.753) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.742) f1: (test=0.741) precision: (test=0.741) recall: (test=0.742) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=best; accuracy: (test=0.735) f1: (test=0.735) precision: (test=0.737) recall: (test=0.735) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.695) f1: (test=0.695) precision: (test=0.696) recall: (test=0.695) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.688) f1: (test=0.689) precision: (test=0.695) recall: (test=0.688) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.715) recall: (test=0.713) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.702) f1: (test=0.701) precision: (test=0.703) recall: (test=0.703) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=5, splitter=random; accuracy: (test=0.703) f1: (test=0.702) precision: (test=0.704) recall: (test=0.704) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.753) f1: (test=0.754) precision: (test=0.754) recall: (test=0.753) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.756) f1: (test=0.756) precision: (test=0.757) recall: (test=0.756) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.752) f1: (test=0.752) precision: (test=0.752) recall: (test=0.752) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.746) f1: (test=0.745) precision: (test=0.745) recall: (test=0.746) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best; accuracy: (test=0.734) f1: (test=0.734) precision: (test=0.734) recall: (test=0.734) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.728) f1: (test=0.729) precision: (test=0.731) recall: (test=0.728) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.726) f1: (test=0.725) precision: (test=0.725) recall: (test=0.726) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.725) f1: (test=0.726) precision: (test=0.727) recall: (test=0.725) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.719) f1: (test=0.719) precision: (test=0.720) recall: (test=0.719) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random; accuracy: (test=0.717) f1: (test=0.717) precision: (test=0.719) recall: (test=0.717) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.753) f1: (test=0.754) precision: (test=0.754) recall: (test=0.753) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.759) f1: (test=0.760) precision: (test=0.761) recall: (test=0.759) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.747) f1: (test=0.748) precision: (test=0.749) recall: (test=0.747) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.745) f1: (test=0.745) precision: (test=0.745) recall: (test=0.745) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=best; accuracy: (test=0.755) f1: (test=0.755) precision: (test=0.755) recall: (test=0.755) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.719) f1: (test=0.719) precision: (test=0.720) recall: (test=0.719) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.739) f1: (test=0.739) precision: (test=0.740) recall: (test=0.739) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.715) recall: (test=0.713) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.725) f1: (test=0.724) precision: (test=0.725) recall: (test=0.726) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=2, splitter=random; accuracy: (test=0.724) f1: (test=0.724) precision: (test=0.726) recall: (test=0.724) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.754) f1: (test=0.754) precision: (test=0.755) recall: (test=0.754) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.756) f1: (test=0.756) precision: (test=0.756) recall: (test=0.756) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.751) f1: (test=0.752) precision: (test=0.754) recall: (test=0.751) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.750) f1: (test=0.750) precision: (test=0.750) recall: (test=0.750) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=best; accuracy: (test=0.760) f1: (test=0.760) precision: (test=0.760) recall: (test=0.760) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.703) f1: (test=0.704) precision: (test=0.707) recall: (test=0.703) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.740) f1: (test=0.740) precision: (test=0.741) recall: (test=0.740) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.719) f1: (test=0.720) precision: (test=0.721) recall: (test=0.719) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.731) f1: (test=0.729) precision: (test=0.731) recall: (test=0.731) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=5, splitter=random; accuracy: (test=0.718) f1: (test=0.719) precision: (test=0.722) recall: (test=0.718) total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.757) f1: (test=0.757) precision: (test=0.758) recall: (test=0.757) total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.766) f1: (test=0.767) precision: (test=0.768) recall: (test=0.766) total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.753) f1: (test=0.754) precision: (test=0.755) recall: (test=0.753) total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.748) f1: (test=0.747) precision: (test=0.747) recall: (test=0.748) total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=best; accuracy: (test=0.759) f1: (test=0.759) precision: (test=0.760) recall: (test=0.759) total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.722) f1: (test=0.722) precision: (test=0.723) recall: (test=0.722) total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.726) f1: (test=0.725) precision: (test=0.726) recall: (test=0.726) total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.709) f1: (test=0.709) precision: (test=0.711) recall: (test=0.709) total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.721) f1: (test=0.722) precision: (test=0.725) recall: (test=0.721) total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, max_features=None, min_samples_leaf=4, min_samples_split=10, splitter=random; accuracy: (test=0.740) f1: (test=0.739) precision: (test=0.740) recall: (test=0.740) total time=   0.0s
# Лучшие параметры после отбора признаков:
# {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}

# %% [markdown]
# ### 3.6. Сравнить метрики

# %%
best_result_tree = pd.DataFrame(clf_tree.cv_results_).iloc[clf_tree.best_index_]

# %%
print(f"Accuracy: {best_result_tree['mean_test_accuracy']}")
print(f"Precision: {best_result_tree['mean_test_precision']}")
print(f"Recall: {best_result_tree['mean_test_recall']}")
print(f"F1: {best_result_tree['mean_test_f1']}")
# Out:
# Accuracy: 0.7555149744338934
# Precision: 0.7605306227377915
# Recall: 0.755610068932276
# F1: 0.757179413780155

# %% [markdown]
# Видно, что метрики оценки качества незначительно уменьшились, зато получилось уменьшить объём данных.

# %% [markdown]
# ## 4. Случайный лес

# %% [markdown]
# ### 4.1 С использованием GridSearchCV осуществить подбор гиперпараметра RandomForestClassifier

# %%
# Настройка параметров для RandomForestClassifier
parameters_rf = {
    'n_estimators': [50, 100],
    "criterion": ["gini", "entropy"],
    "max_depth": [None, 10],
    "max_features": ['sqrt', 'log2']
}

# %%
# Обучение и подбор параметров для RandomForestClassifier
clf_rf = GridSearchCV(RandomForestClassifier(), parameters_rf, scoring=scores, refit='f1', cv=5, verbose=4)
clf_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.791) f1: (test=0.791) precision: (test=0.792) recall: (test=0.791) total time=   1.3s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.802) f1: (test=0.802) precision: (test=0.802) recall: (test=0.803) total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.789) f1: (test=0.789) precision: (test=0.788) recall: (test=0.789) total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.799) f1: (test=0.799) precision: (test=0.799) recall: (test=0.799) total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.781) f1: (test=0.781) precision: (test=0.782) recall: (test=0.781) total time=   1.7s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.791) f1: (test=0.792) precision: (test=0.792) recall: (test=0.791) total time=   2.9s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.802) f1: (test=0.802) precision: (test=0.802) recall: (test=0.803) total time=   2.5s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.793) f1: (test=0.793) precision: (test=0.793) recall: (test=0.793) total time=   2.4s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.802) f1: (test=0.802) precision: (test=0.802) recall: (test=0.802) total time=   2.4s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.791) f1: (test=0.791) precision: (test=0.792) recall: (test=0.791) total time=   2.9s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.788) f1: (test=0.789) precision: (test=0.790) recall: (test=0.788) total time=   1.6s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.807) f1: (test=0.807) precision: (test=0.807) recall: (test=0.807) total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.789) f1: (test=0.790) precision: (test=0.790) recall: (test=0.789) total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.795) f1: (test=0.795) precision: (test=0.795) recall: (test=0.795) total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.787) f1: (test=0.788) precision: (test=0.789) recall: (test=0.788) total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.792) f1: (test=0.793) precision: (test=0.794) recall: (test=0.792) total time=   2.4s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.808) f1: (test=0.808) precision: (test=0.808) recall: (test=0.808) total time=   2.6s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.795) f1: (test=0.795) precision: (test=0.795) recall: (test=0.795) total time=   3.3s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.801) f1: (test=0.801) precision: (test=0.801) recall: (test=0.801) total time=   2.4s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.793) f1: (test=0.793) precision: (test=0.795) recall: (test=0.793) total time=   2.4s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.767) f1: (test=0.769) precision: (test=0.774) recall: (test=0.767) total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.792) f1: (test=0.793) precision: (test=0.795) recall: (test=0.792) total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.772) f1: (test=0.773) precision: (test=0.774) recall: (test=0.772) total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.778) f1: (test=0.778) precision: (test=0.779) recall: (test=0.778) total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.776) f1: (test=0.778) precision: (test=0.782) recall: (test=0.776) total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.772) f1: (test=0.774) precision: (test=0.777) recall: (test=0.772) total time=   2.4s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.791) f1: (test=0.792) precision: (test=0.795) recall: (test=0.791) total time=   2.1s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.776) f1: (test=0.778) precision: (test=0.779) recall: (test=0.777) total time=   1.8s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.783) f1: (test=0.783) precision: (test=0.785) recall: (test=0.783) total time=   1.8s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.780) f1: (test=0.781) precision: (test=0.784) recall: (test=0.780) total time=   1.8s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.760) f1: (test=0.763) precision: (test=0.767) recall: (test=0.760) total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.787) f1: (test=0.788) precision: (test=0.789) recall: (test=0.787) total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.786) f1: (test=0.787) precision: (test=0.788) recall: (test=0.786) total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.776) f1: (test=0.776) precision: (test=0.778) recall: (test=0.776) total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.776) f1: (test=0.777) precision: (test=0.780) recall: (test=0.776) total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.771) f1: (test=0.773) precision: (test=0.776) recall: (test=0.771) total time=   2.4s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.786) f1: (test=0.787) precision: (test=0.789) recall: (test=0.786) total time=   1.8s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.778) f1: (test=0.779) precision: (test=0.781) recall: (test=0.778) total time=   1.9s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.778) f1: (test=0.779) precision: (test=0.781) recall: (test=0.778) total time=   1.9s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.783) f1: (test=0.784) precision: (test=0.787) recall: (test=0.783) total time=   1.8s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.790) f1: (test=0.791) precision: (test=0.792) recall: (test=0.790) total time=   1.6s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.801) f1: (test=0.801) precision: (test=0.801) recall: (test=0.801) total time=   2.1s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.791) f1: (test=0.790) precision: (test=0.790) recall: (test=0.791) total time=   2.0s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.793) f1: (test=0.793) precision: (test=0.793) recall: (test=0.793) total time=   1.6s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.789) f1: (test=0.789) precision: (test=0.790) recall: (test=0.789) total time=   1.6s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.798) f1: (test=0.798) precision: (test=0.798) recall: (test=0.798) total time=   3.1s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.806) f1: (test=0.806) precision: (test=0.806) recall: (test=0.807) total time=   3.1s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.796) f1: (test=0.796) precision: (test=0.796) recall: (test=0.796) total time=   4.1s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.795) f1: (test=0.795) precision: (test=0.795) recall: (test=0.796) total time=   3.1s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.795) f1: (test=0.795) precision: (test=0.796) recall: (test=0.795) total time=   3.1s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.781) f1: (test=0.782) precision: (test=0.784) recall: (test=0.781) total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.802) f1: (test=0.801) precision: (test=0.801) recall: (test=0.802) total time=   1.7s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.795) f1: (test=0.795) precision: (test=0.795) recall: (test=0.795) total time=   2.3s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.793) f1: (test=0.793) precision: (test=0.793) recall: (test=0.793) total time=   1.7s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.785) f1: (test=0.785) precision: (test=0.786) recall: (test=0.785) total time=   1.6s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.789) f1: (test=0.790) precision: (test=0.791) recall: (test=0.789) total time=   3.1s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.809) f1: (test=0.808) precision: (test=0.808) recall: (test=0.809) total time=   3.5s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.797) f1: (test=0.797) precision: (test=0.797) recall: (test=0.797) total time=   4.8s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.800) f1: (test=0.799) precision: (test=0.799) recall: (test=0.800) total time=   3.1s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.790) f1: (test=0.791) precision: (test=0.792) recall: (test=0.790) total time=   3.1s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.772) f1: (test=0.774) precision: (test=0.777) recall: (test=0.772) total time=   1.2s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.789) f1: (test=0.789) precision: (test=0.789) recall: (test=0.789) total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.776) f1: (test=0.777) precision: (test=0.778) recall: (test=0.776) total time=   1.2s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.771) f1: (test=0.771) precision: (test=0.772) recall: (test=0.771) total time=   1.6s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.780) f1: (test=0.781) precision: (test=0.783) recall: (test=0.780) total time=   1.7s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.770) f1: (test=0.772) precision: (test=0.775) recall: (test=0.770) total time=   2.4s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.788) f1: (test=0.787) precision: (test=0.787) recall: (test=0.788) total time=   2.3s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.782) f1: (test=0.783) precision: (test=0.784) recall: (test=0.782) total time=   2.3s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.777) f1: (test=0.777) precision: (test=0.778) recall: (test=0.777) total time=   2.3s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.775) f1: (test=0.776) precision: (test=0.779) recall: (test=0.775) total time=   3.0s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.768) f1: (test=0.770) precision: (test=0.772) recall: (test=0.769) total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.789) f1: (test=0.789) precision: (test=0.790) recall: (test=0.789) total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.780) f1: (test=0.781) precision: (test=0.782) recall: (test=0.780) total time=   1.2s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.774) f1: (test=0.773) precision: (test=0.774) recall: (test=0.774) total time=   1.2s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.777) f1: (test=0.778) precision: (test=0.780) recall: (test=0.777) total time=   1.2s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.769) f1: (test=0.771) precision: (test=0.774) recall: (test=0.769) total time=   2.3s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.791) f1: (test=0.792) precision: (test=0.793) recall: (test=0.791) total time=   2.4s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.779) f1: (test=0.780) precision: (test=0.782) recall: (test=0.779) total time=   3.3s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.773) f1: (test=0.773) precision: (test=0.774) recall: (test=0.773) total time=   2.3s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.778) f1: (test=0.779) precision: (test=0.781) recall: (test=0.778) total time=   2.3s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              refit='f1',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'f1': make_scorer(f1_score, average=macro),
#                       'precision': make_scorer(precision_score, average=macro),
#                       'recall': make_scorer(recall_score, average=macro)},
#              verbose=4)

# %% [markdown]
# ### 4.2 Вывести гиперпараметры лучшей модели и ее метрики

# %%
print("Лучшие параметры для RandomForestClassifier: ")
print(clf_rf.best_params_)
# Out:
# Лучшие параметры для RandomForestClassifier:
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}

# %%
results_rf = pd.DataFrame(clf_rf.cv_results_)
best_result_rf = results_rf[results_rf['rank_test_f1'] == 1]

# %% [markdown]
# ### 4.3 Осуществить фильтрацию признаков

# %%
# Важность признаков
feature_importance_rf = {X_train.columns[i]: clf_rf.best_estimator_.feature_importances_[i] for i in range(len(X_train.columns))}
feature_importance_items_rf = sorted(feature_importance_rf.items(), key=lambda x: x[1])
feature_importance_rf = dict(feature_importance_items_rf)
print("Feature importances for RandomForestClassifier:")
print(feature_importance_rf)
# Out:
# Feature importances for RandomForestClassifier:
# {'ocean_proximity_ISLAND': 2.5332867564056996e-05, 'ocean_proximity_NEAR BAY': 0.005064732936989341, 'ocean_proximity_NEAR OCEAN': 0.008984604576501793, 'total_bedrooms': 0.06261681989912016, 'households': 0.06305800536454856, 'housing_median_age': 0.06337007773869226, 'total_rooms': 0.07567618670828948, 'population': 0.07976396644995708, 'ocean_proximity_INLAND': 0.11537719398821107, 'latitude': 0.1354222002115717, 'longitude': 0.14271612515720986, 'median_income': 0.24792475410134485}

# %%
# Перетренировка модели с использованием только важных признаков
clf_rf = GridSearchCV(RandomForestClassifier(), parameters_rf, scoring=scores, refit='f1', cv=5, verbose=4)
clf_rf.fit(X_train_f, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.792) f1: (test=0.792) precision: (test=0.793) recall: (test=0.792) total time=   1.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.804) f1: (test=0.803) precision: (test=0.803) recall: (test=0.804) total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.789) f1: (test=0.790) precision: (test=0.790) recall: (test=0.789) total time=   1.5s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.783) f1: (test=0.782) precision: (test=0.782) recall: (test=0.784) total time=   1.2s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.785) f1: (test=0.786) precision: (test=0.788) recall: (test=0.785) total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.791) f1: (test=0.792) precision: (test=0.793) recall: (test=0.792) total time=   2.2s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.800) f1: (test=0.800) precision: (test=0.799) recall: (test=0.800) total time=   2.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.793) f1: (test=0.793) precision: (test=0.793) recall: (test=0.793) total time=   2.1s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.796) f1: (test=0.795) precision: (test=0.795) recall: (test=0.796) total time=   2.3s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.795) f1: (test=0.796) precision: (test=0.797) recall: (test=0.795) total time=   2.9s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.799) f1: (test=0.799) precision: (test=0.800) recall: (test=0.799) total time=   1.5s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.810) f1: (test=0.810) precision: (test=0.810) recall: (test=0.810) total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.805) f1: (test=0.805) precision: (test=0.806) recall: (test=0.805) total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.803) f1: (test=0.803) precision: (test=0.803) recall: (test=0.803) total time=   1.4s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.797) f1: (test=0.797) precision: (test=0.799) recall: (test=0.797) total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.804) f1: (test=0.805) precision: (test=0.806) recall: (test=0.804) total time=   3.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.812) f1: (test=0.812) precision: (test=0.813) recall: (test=0.812) total time=   3.6s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.801) f1: (test=0.800) precision: (test=0.800) recall: (test=0.801) total time=   2.8s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.808) f1: (test=0.808) precision: (test=0.808) recall: (test=0.808) total time=   2.9s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.800) f1: (test=0.801) precision: (test=0.802) recall: (test=0.800) total time=   2.9s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.766) f1: (test=0.768) precision: (test=0.772) recall: (test=0.766) total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.779) f1: (test=0.780) precision: (test=0.782) recall: (test=0.779) total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.774) f1: (test=0.775) precision: (test=0.777) recall: (test=0.774) total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.773) f1: (test=0.773) precision: (test=0.775) recall: (test=0.773) total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.774) f1: (test=0.775) precision: (test=0.778) recall: (test=0.774) total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.768) f1: (test=0.770) precision: (test=0.774) recall: (test=0.768) total time=   1.6s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.780) f1: (test=0.781) precision: (test=0.783) recall: (test=0.780) total time=   1.7s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.778) f1: (test=0.780) precision: (test=0.783) recall: (test=0.778) total time=   1.6s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.774) f1: (test=0.775) precision: (test=0.776) recall: (test=0.774) total time=   1.6s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.785) f1: (test=0.786) precision: (test=0.788) recall: (test=0.785) total time=   1.6s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.773) f1: (test=0.776) precision: (test=0.780) recall: (test=0.773) total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.791) f1: (test=0.792) precision: (test=0.794) recall: (test=0.791) total time=   1.5s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.778) f1: (test=0.780) precision: (test=0.782) recall: (test=0.778) total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.777) f1: (test=0.778) precision: (test=0.780) recall: (test=0.777) total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.787) f1: (test=0.788) precision: (test=0.791) recall: (test=0.787) total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.777) f1: (test=0.779) precision: (test=0.782) recall: (test=0.777) total time=   2.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.799) f1: (test=0.800) precision: (test=0.802) recall: (test=0.799) total time=   2.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.785) f1: (test=0.786) precision: (test=0.788) recall: (test=0.785) total time=   2.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.788) f1: (test=0.789) precision: (test=0.791) recall: (test=0.788) total time=   3.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.792) f1: (test=0.794) precision: (test=0.798) recall: (test=0.792) total time=   3.3s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.791) f1: (test=0.791) precision: (test=0.792) recall: (test=0.791) total time=   1.4s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.797) f1: (test=0.797) precision: (test=0.797) recall: (test=0.797) total time=   1.4s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.794) f1: (test=0.794) precision: (test=0.794) recall: (test=0.794) total time=   1.4s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.797) f1: (test=0.796) precision: (test=0.796) recall: (test=0.797) total time=   1.4s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50; accuracy: (test=0.788) f1: (test=0.788) precision: (test=0.791) recall: (test=0.788) total time=   1.4s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.801) f1: (test=0.802) precision: (test=0.802) recall: (test=0.801) total time=   3.0s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.810) f1: (test=0.810) precision: (test=0.810) recall: (test=0.811) total time=   3.6s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.795) f1: (test=0.795) precision: (test=0.795) recall: (test=0.795) total time=   2.7s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.799) f1: (test=0.799) precision: (test=0.799) recall: (test=0.799) total time=   2.8s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100; accuracy: (test=0.786) f1: (test=0.787) precision: (test=0.788) recall: (test=0.787) total time=   2.8s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.797) f1: (test=0.798) precision: (test=0.799) recall: (test=0.797) total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.804) f1: (test=0.804) precision: (test=0.804) recall: (test=0.804) total time=   2.2s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.798) f1: (test=0.798) precision: (test=0.799) recall: (test=0.798) total time=   1.8s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.804) f1: (test=0.804) precision: (test=0.804) recall: (test=0.804) total time=   1.8s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50; accuracy: (test=0.790) f1: (test=0.790) precision: (test=0.792) recall: (test=0.790) total time=   1.8s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.797) f1: (test=0.798) precision: (test=0.799) recall: (test=0.797) total time=   3.7s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.811) f1: (test=0.811) precision: (test=0.811) recall: (test=0.811) total time=   4.5s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.801) f1: (test=0.801) precision: (test=0.801) recall: (test=0.801) total time=   3.6s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.805) f1: (test=0.804) precision: (test=0.804) recall: (test=0.805) total time=   3.7s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100; accuracy: (test=0.799) f1: (test=0.799) precision: (test=0.800) recall: (test=0.799) total time=   4.7s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.764) f1: (test=0.766) precision: (test=0.770) recall: (test=0.764) total time=   1.0s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.788) f1: (test=0.788) precision: (test=0.789) recall: (test=0.788) total time=   1.0s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.773) f1: (test=0.773) precision: (test=0.774) recall: (test=0.773) total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.775) f1: (test=0.775) precision: (test=0.775) recall: (test=0.776) total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=50; accuracy: (test=0.781) f1: (test=0.782) precision: (test=0.784) recall: (test=0.781) total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.774) f1: (test=0.776) precision: (test=0.779) recall: (test=0.774) total time=   2.0s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.785) f1: (test=0.786) precision: (test=0.787) recall: (test=0.785) total time=   2.1s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.774) f1: (test=0.775) precision: (test=0.777) recall: (test=0.774) total time=   3.1s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.768) f1: (test=0.768) precision: (test=0.769) recall: (test=0.769) total time=   2.1s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100; accuracy: (test=0.773) f1: (test=0.774) precision: (test=0.776) recall: (test=0.773) total time=   2.0s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.775) f1: (test=0.777) precision: (test=0.780) recall: (test=0.775) total time=   1.4s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.801) f1: (test=0.802) precision: (test=0.803) recall: (test=0.801) total time=   1.4s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.785) f1: (test=0.786) precision: (test=0.788) recall: (test=0.785) total time=   1.4s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.785) f1: (test=0.785) precision: (test=0.787) recall: (test=0.785) total time=   1.4s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=50; accuracy: (test=0.783) f1: (test=0.785) precision: (test=0.787) recall: (test=0.784) total time=   1.9s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.775) f1: (test=0.778) precision: (test=0.781) recall: (test=0.775) total time=   3.4s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.791) f1: (test=0.792) precision: (test=0.794) recall: (test=0.791) total time=   2.8s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.783) f1: (test=0.785) precision: (test=0.786) recall: (test=0.783) total time=   2.8s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.784) f1: (test=0.785) precision: (test=0.786) recall: (test=0.784) total time=   3.1s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100; accuracy: (test=0.784) f1: (test=0.785) precision: (test=0.788) recall: (test=0.784) total time=   3.5s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              refit='f1',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'f1': make_scorer(f1_score, average=macro),
#                       'precision': make_scorer(precision_score, average=macro),
#                       'recall': make_scorer(recall_score, average=macro)},
#              verbose=4)

# %% [markdown]
# ### 4.5 Параметры для лучшей модели

# %%
print("Лучшие параметры после отбора признаков: ")
print(clf_rf.best_params_)
# Out:
# Лучшие параметры после отбора признаков:
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 100}

# %% [markdown]
# ### 4.6 Сравнение метрик до и после фильтрации

# %%
print("Метрики до фильтрации: ")
print(f"Accuracy: {best_result_rf['mean_test_accuracy'].values[0]}")
print(f"Precision: {best_result_rf['mean_test_precision'].values[0]}")
print(f"Recall: {best_result_rf['mean_test_recall'].values[0]}")
print(f"F1: {best_result_rf['mean_test_f1'].values[0]}")
# Out:
# Метрики до фильтрации:
# Accuracy: 0.7981008035062089
# Precision: 0.7983624052706506
# Recall: 0.7982085744741002
# F1: 0.7981074175253323

# %%
best_result_rf = pd.DataFrame(clf_rf.cv_results_).iloc[clf_rf.best_index_]

print(f"Accuracy: {best_result_rf['mean_test_accuracy']}")
print(f"Precision: {best_result_rf['mean_test_precision']}")
print(f"Recall: {best_result_rf['mean_test_recall']}")
print(f"F1: {best_result_rf['mean_test_f1']}")
# Out:
# Accuracy: 0.8050401753104456
# Precision: 0.8059211739355714
# Recall: 0.8051359844907953
# F1: 0.8053087021913525

# %% [markdown]
# Из результатов видно, что значение количественных метрик незначительно, но улучшилось

# %% [markdown]
# ## 5. Алгоритм K - ближайших соседей

# %% [markdown]
# ### 5.1 GridSearch для алгоритма

# %%
# Настройка параметров для KNeighborsClassifier
parameters_knn = {
    'n_neighbors': [2, 5, 10, 20, 50]
}

# %%
# Обучение и подбор параметров для KNeighborsClassifier
clf_knn = GridSearchCV(KNeighborsClassifier(), parameters_knn, scoring=scores, refit='f1', cv=5, verbose=4)
clf_knn.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END n_neighbors=2; accuracy: (test=0.693) f1: (test=0.691) precision: (test=0.710) recall: (test=0.693) total time=   0.6s
# [CV 2/5] END n_neighbors=2; accuracy: (test=0.696) f1: (test=0.694) precision: (test=0.715) recall: (test=0.697) total time=   0.5s
# [CV 3/5] END n_neighbors=2; accuracy: (test=0.693) f1: (test=0.691) precision: (test=0.710) recall: (test=0.693) total time=   0.5s
# [CV 4/5] END n_neighbors=2; accuracy: (test=0.687) f1: (test=0.684) precision: (test=0.706) recall: (test=0.687) total time=   0.4s
# [CV 5/5] END n_neighbors=2; accuracy: (test=0.686) f1: (test=0.684) precision: (test=0.706) recall: (test=0.687) total time=   0.4s
# [CV 1/5] END n_neighbors=5; accuracy: (test=0.715) f1: (test=0.716) precision: (test=0.719) recall: (test=0.716) total time=   0.4s
# [CV 2/5] END n_neighbors=5; accuracy: (test=0.730) f1: (test=0.730) precision: (test=0.732) recall: (test=0.730) total time=   0.3s
# [CV 3/5] END n_neighbors=5; accuracy: (test=0.721) f1: (test=0.721) precision: (test=0.723) recall: (test=0.721) total time=   0.3s
# [CV 4/5] END n_neighbors=5; accuracy: (test=0.737) f1: (test=0.736) precision: (test=0.738) recall: (test=0.737) total time=   0.3s
# [CV 5/5] END n_neighbors=5; accuracy: (test=0.716) f1: (test=0.716) precision: (test=0.718) recall: (test=0.716) total time=   0.3s
# [CV 1/5] END n_neighbors=10; accuracy: (test=0.720) f1: (test=0.721) precision: (test=0.725) recall: (test=0.720) total time=   0.4s
# [CV 2/5] END n_neighbors=10; accuracy: (test=0.731) f1: (test=0.732) precision: (test=0.736) recall: (test=0.731) total time=   0.3s
# [CV 3/5] END n_neighbors=10; accuracy: (test=0.723) f1: (test=0.723) precision: (test=0.727) recall: (test=0.723) total time=   0.3s
# [CV 4/5] END n_neighbors=10; accuracy: (test=0.740) f1: (test=0.741) precision: (test=0.745) recall: (test=0.740) total time=   0.3s
# [CV 5/5] END n_neighbors=10; accuracy: (test=0.725) f1: (test=0.724) precision: (test=0.728) recall: (test=0.725) total time=   0.3s
# [CV 1/5] END n_neighbors=20; accuracy: (test=0.724) f1: (test=0.726) precision: (test=0.730) recall: (test=0.724) total time=   0.4s
# [CV 2/5] END n_neighbors=20; accuracy: (test=0.734) f1: (test=0.735) precision: (test=0.739) recall: (test=0.734) total time=   0.4s
# [CV 3/5] END n_neighbors=20; accuracy: (test=0.723) f1: (test=0.724) precision: (test=0.729) recall: (test=0.723) total time=   0.3s
# [CV 4/5] END n_neighbors=20; accuracy: (test=0.733) f1: (test=0.733) precision: (test=0.737) recall: (test=0.733) total time=   0.3s
# [CV 5/5] END n_neighbors=20; accuracy: (test=0.731) f1: (test=0.731) precision: (test=0.734) recall: (test=0.731) total time=   0.3s
# [CV 1/5] END n_neighbors=50; accuracy: (test=0.712) f1: (test=0.714) precision: (test=0.719) recall: (test=0.712) total time=   0.5s
# [CV 2/5] END n_neighbors=50; accuracy: (test=0.726) f1: (test=0.728) precision: (test=0.733) recall: (test=0.727) total time=   0.4s
# [CV 3/5] END n_neighbors=50; accuracy: (test=0.720) f1: (test=0.722) precision: (test=0.727) recall: (test=0.720) total time=   0.4s
# [CV 4/5] END n_neighbors=50; accuracy: (test=0.722) f1: (test=0.722) precision: (test=0.727) recall: (test=0.722) total time=   0.4s
# [CV 5/5] END n_neighbors=50; accuracy: (test=0.715) f1: (test=0.716) precision: (test=0.721) recall: (test=0.716) total time=   0.4s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [2, 5, 10, 20, 50]}, refit='f1',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'f1': make_scorer(f1_score, average=macro),
#                       'precision': make_scorer(precision_score, average=macro),
#                       'recall': make_scorer(recall_score, average=macro)},
#              verbose=4)

# %% [markdown]
# ### 5.2 Лучшие параметры и метрики

# %%
print("Лучшие параметры для KNeighborsClassifier: ")
print(clf_knn.best_params_)
# Out:
# Лучшие параметры для KNeighborsClassifier:
# {'n_neighbors': 20}

# %%
results_knn = pd.DataFrame(clf_knn.cv_results_)
best_result_knn = results_knn[results_knn['rank_test_f1'] == 1]
print(f"Accuracy: {best_result_knn['mean_test_accuracy'].values[0]}")
print(f"Precision: {best_result_knn['mean_test_precision'].values[0]}")
print(f"Recall: {best_result_knn['mean_test_recall'].values[0]}")
print(f"F1: {best_result_knn['mean_test_f1'].values[0]}")
# Out:
# Accuracy: 0.7287801314828342
# Precision: 0.7338756673077464
# Recall: 0.7289343191525159
# F1: 0.7297914550418051

# %% [markdown]
# ### 5.3 Обучить на отфильтрованных данных

# %%
# Перетренировка модели с использованием только важных признаков
clf_knn.fit(X_train_f, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END n_neighbors=2; accuracy: (test=0.695) f1: (test=0.693) precision: (test=0.712) recall: (test=0.695) total time=   0.2s
# [CV 2/5] END n_neighbors=2; accuracy: (test=0.697) f1: (test=0.694) precision: (test=0.715) recall: (test=0.697) total time=   0.2s
# [CV 3/5] END n_neighbors=2; accuracy: (test=0.688) f1: (test=0.685) precision: (test=0.705) recall: (test=0.688) total time=   0.3s
# [CV 4/5] END n_neighbors=2; accuracy: (test=0.689) f1: (test=0.686) precision: (test=0.707) recall: (test=0.689) total time=   0.2s
# [CV 5/5] END n_neighbors=2; accuracy: (test=0.684) f1: (test=0.681) precision: (test=0.707) recall: (test=0.684) total time=   0.2s
# [CV 1/5] END n_neighbors=5; accuracy: (test=0.721) f1: (test=0.721) precision: (test=0.724) recall: (test=0.721) total time=   0.3s
# [CV 2/5] END n_neighbors=5; accuracy: (test=0.726) f1: (test=0.726) precision: (test=0.729) recall: (test=0.727) total time=   0.2s
# [CV 3/5] END n_neighbors=5; accuracy: (test=0.713) f1: (test=0.713) precision: (test=0.715) recall: (test=0.713) total time=   0.2s
# [CV 4/5] END n_neighbors=5; accuracy: (test=0.735) f1: (test=0.734) precision: (test=0.736) recall: (test=0.735) total time=   0.3s
# [CV 5/5] END n_neighbors=5; accuracy: (test=0.718) f1: (test=0.718) precision: (test=0.720) recall: (test=0.719) total time=   0.4s
# [CV 1/5] END n_neighbors=10; accuracy: (test=0.722) f1: (test=0.723) precision: (test=0.729) recall: (test=0.722) total time=   0.4s
# [CV 2/5] END n_neighbors=10; accuracy: (test=0.726) f1: (test=0.726) precision: (test=0.730) recall: (test=0.727) total time=   0.4s
# [CV 3/5] END n_neighbors=10; accuracy: (test=0.730) f1: (test=0.731) precision: (test=0.737) recall: (test=0.730) total time=   0.4s
# [CV 4/5] END n_neighbors=10; accuracy: (test=0.732) f1: (test=0.731) precision: (test=0.735) recall: (test=0.732) total time=   0.4s
# [CV 5/5] END n_neighbors=10; accuracy: (test=0.724) f1: (test=0.724) precision: (test=0.728) recall: (test=0.725) total time=   0.4s
# [CV 1/5] END n_neighbors=20; accuracy: (test=0.722) f1: (test=0.724) precision: (test=0.730) recall: (test=0.723) total time=   0.4s
# [CV 2/5] END n_neighbors=20; accuracy: (test=0.734) f1: (test=0.735) precision: (test=0.738) recall: (test=0.735) total time=   0.3s
# [CV 3/5] END n_neighbors=20; accuracy: (test=0.731) f1: (test=0.733) precision: (test=0.738) recall: (test=0.731) total time=   0.3s
# [CV 4/5] END n_neighbors=20; accuracy: (test=0.729) f1: (test=0.729) precision: (test=0.733) recall: (test=0.729) total time=   0.2s
# [CV 5/5] END n_neighbors=20; accuracy: (test=0.726) f1: (test=0.727) precision: (test=0.732) recall: (test=0.727) total time=   0.3s
# [CV 1/5] END n_neighbors=50; accuracy: (test=0.714) f1: (test=0.716) precision: (test=0.722) recall: (test=0.714) total time=   0.3s
# [CV 2/5] END n_neighbors=50; accuracy: (test=0.723) f1: (test=0.724) precision: (test=0.729) recall: (test=0.723) total time=   0.4s
# [CV 3/5] END n_neighbors=50; accuracy: (test=0.715) f1: (test=0.717) precision: (test=0.723) recall: (test=0.715) total time=   0.3s
# [CV 4/5] END n_neighbors=50; accuracy: (test=0.721) f1: (test=0.721) precision: (test=0.725) recall: (test=0.721) total time=   0.3s
# [CV 5/5] END n_neighbors=50; accuracy: (test=0.711) f1: (test=0.711) precision: (test=0.715) recall: (test=0.711) total time=   0.4s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [2, 5, 10, 20, 50]}, refit='f1',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'f1': make_scorer(f1_score, average=macro),
#                       'precision': make_scorer(precision_score, average=macro),
#                       'recall': make_scorer(recall_score, average=macro)},
#              verbose=4)

# %%
print("Лучшие параметры после отбора признаков: ")
print(clf_knn.best_params_)
# Out:
# Лучшие параметры после отбора признаков:
# {'n_neighbors': 20}

# %% [markdown]
# ### 5.4 Сравнить метрики для отфильтрованных и неотфильтрованных

# %%
print("Метрики до фильтрации: ")
print(f"Accuracy: {best_result_knn['mean_test_accuracy'].values[0]}")
print(f"Precision: {best_result_knn['mean_test_precision'].values[0]}")
print(f"Recall: {best_result_knn['mean_test_recall'].values[0]}")
print(f"F1: {best_result_knn['mean_test_f1'].values[0]}")
# Out:
# Метрики до фильтрации:
# Accuracy: 0.7287801314828342
# Precision: 0.7338756673077464
# Recall: 0.7289343191525159
# F1: 0.7297914550418051

# %%
best_result_knn = pd.DataFrame(clf_knn.cv_results_).iloc[clf_knn.best_index_]
print("Метрики после фильтрации: ")
print(f"Accuracy: {best_result_knn['mean_test_accuracy']}")
print(f"Precision: {best_result_knn['mean_test_precision']}")
print(f"Recall: {best_result_knn['mean_test_recall']}")
print(f"F1: {best_result_knn['mean_test_f1']}")
# Out:
# Метрики после фильтрации:
# Accuracy: 0.7285609934258583
# Precision: 0.7344933226015379
# Recall: 0.7287196678504819
# F1: 0.7295929044572114

# %% [markdown]
# Из результатов видно, что результаты изменились незнакчительно(менее, чем на 0.1%), однако объём данных уменьшен.

# %% [markdown]
# ### 6 Оценка качества построенных моделей

# %%
# Обучение финальных моделей
knn_model = KNeighborsClassifier(n_neighbors=clf_knn.best_params_['n_neighbors'])
tree_model = DecisionTreeClassifier(**clf_tree.best_params_)
forest_model = RandomForestClassifier(**clf_rf.best_params_)

# %%
knn_model.fit(X_train_f, y_train)
tree_model.fit(X_train_f, y_train)
forest_model.fit(X_train_f, y_train)
# Out:
# RandomForestClassifier(max_features='log2')

# %% [markdown]
# ### 6.1 Визуализировать дерево решений

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
dot_data = tree.export_graphviz(tree_model, out_file=None,
feature_names=X_train_f.columns,
class_names=['Low', 'Medium', 'High'],
filled=True, rounded=True,
special_characters=True)

graph = graphviz.Source(dot_data)
graph.render("decision_tree") # сохранение в файл
graph.view() # отображение внутри ноутбука
# Out:
# 'decision_tree.pdf'

# %% [markdown]
# Дерево для удобности просмотра записывается в пдф файл

# %% [markdown]
# ### 6.2 Сравнить лучшие модели

# %%
# Предсказания
y_pred_knn = knn_model.predict(X_test_f)
y_pred_tree = tree_model.predict(X_test_f)
y_pred_forest = forest_model.predict(X_test_f)

print("Результаты для KNeighborsClassifier: ")
print(classification_report(y_test, y_pred_knn))
print("Результаты для DecisionTreeClassifier: ")
print(classification_report(y_test, y_pred_tree))
print("Результаты для RandomForestClassifier: ")
print(classification_report(y_test, y_pred_forest))
# Out:
# Результаты для KNeighborsClassifier:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80      2263
#            1       0.62      0.66      0.64      2241
#            2       0.84      0.70      0.76      2239
#
#     accuracy                           0.74      6743
#    macro avg       0.74      0.74      0.74      6743
# weighted avg       0.74      0.74      0.74      6743
#
# Результаты для DecisionTreeClassifier:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81      2263
#            1       0.64      0.73      0.68      2241
#            2       0.86      0.74      0.79      2239
#
#     accuracy                           0.76      6743
#    macro avg       0.77      0.76      0.76      6743
# weighted avg       0.77      0.76      0.76      6743
#
# Результаты для RandomForestClassifier:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86      2263
#            1       0.73      0.75      0.74      2241
#            2       0.87      0.83      0.85      2239
#
#     accuracy                           0.82      6743
#    macro avg       0.82      0.82      0.82      6743
# weighted avg       0.82      0.82      0.82      6743

# %% [markdown]
# Худшая точность у К ближайших соседей, наибольшая точность у случайного леса
